# %% [markdown]
# ## import whatever I will need in the proceeding codes

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import json

# %% [markdown]
# ## get ign data from the computer as pandas dataframe

# %%
game_data=pd.read_csv('C:/Users/shshi/Desktop/Capstone 1/DATA/ign.csv/ign.csv',index_col=0,parse_dates=True)

# %%
gamedf=pd.DataFrame(data=game_data)

# %%
gamedf.head(3)
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12

# %% [markdown]
# ## Change score_phrase, platform, genre into numerical value using label encoder
# ## All the respective number and what those stand for will be stored in 'column name'_class

# %%
score_phrase_list=list(gamedf['score_phrase'])

# %%
score_phrase_num=preprocessing.LabelEncoder()

# %%
score_phrase_num.fit(score_phrase_list)
# Out:
# LabelEncoder()

# %%
new_scorephrase=score_phrase_num.transform(score_phrase_list)

# %%
score_phrase_class=score_phrase_num.classes_

# %%
gamedf['score_phrase']=new_scorephrase

# %% [markdown]
# ## Change whether or not it has editor's choice into 1 and 0

# %%
editorchoice={'Y':1,'N':0}

# %%
game_data.editors_choice=[editorchoice[item] for item in game_data.editors_choice]

# %% [markdown]
# ## make the items in 'platform' and 'genre' into numeric values using label encoder

# %%
platform_list=list(gamedf['platform'])

# %%
platform_num=preprocessing.LabelEncoder()

# %%
platform_num.fit(platform_list)
# Out:
# LabelEncoder()

# %%
new_platform=platform_num.transform(platform_list)

# %%
platform_class=platform_num.classes_

# %%
gamedf['platform']=new_platform

# %%
genre_list=list(gamedf['genre'])

genre_num=preprocessing.LabelEncoder()

genre_num.fit(genre_list)

new_genre=genre_num.transform(genre_list)

genre_class=genre_num.classes_

gamedf['genre']=new_genre

# %%
ign=game_data

# %%
ign.head(3)
# Out:
#    score_phrase                                              title  \
# 0             0                            LittleBigPlanet PS Vita
# 1             0  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2             5                               Splice: Tree of Life
#
#                                                  url  platform  score  genre  \
# 0             /games/littlebigplanet-vita/vita-98907        35    9.0     63
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...        35    9.0     63
# 2                          /games/splice/ipad-141070        56    8.5     68
#
#    editors_choice  release_year  release_month  release_day
# 0               1          2012              9           12
# 1               1          2012              9           12
# 2               0          2012              9           12

# %% [markdown]
# ## get data from jsonline file regarding actual reviews from players

# %%
garryfile='C:/Users\shshi/Desktop/Capstone 1/DATA/steam_reviews-master/steam_reviews-master/data/Garrys_Mod.jsonlines'

# %%
garry=pd.read_json(garryfile,lines=True)
garry.head()
# Out:
#                                 achievement_progress            date_posted  \
# 0  {'num_achievements_percentage': 0.886100386100...   Aug 11, 2014, 6:26PM
# 1  {'num_achievements_percentage': 1.0, 'num_achi...  Jun 25, 2014, 11:46AM
# 2  {'num_achievements_percentage': 0.827586206896...   Dec 28, 2014, 4:47PM
# 3  {'num_achievements_percentage': 0.241379310344...   Dec 22, 2014, 8:48PM
# 4  {'num_achievements_percentage': 0.517241379310...   Oct 3, 2014, 11:01AM
#
#            date_updated  found_helpful_percentage  friend_player_level  \
# 0                  None                  0.951427                 25.0
# 1                  None                  0.922814                 30.0
# 2  Apr 20, 2015, 5:42PM                  0.916968                  6.0
# 3   Feb 9, 2015, 6:11PM                  0.929558                 18.0
# 4                  None                  0.911138                 12.0
#
#    num_badges  num_comments  num_found_funny  num_found_helpful  \
# 0        37.0           126                1               5700
# 1        28.0            97                0               4328
# 2         4.0           261                1               3810
# 3        18.0            28                2               1346
# 4        10.0            64                1               2994
#
#    num_found_unhelpful               ...                num_workshop_items  \
# 0                  291               ...                                 3
# 1                  362               ...                                26
# 2                  345               ...                                 1
# 3                  102               ...                                 0
# 4                  292               ...                                 0
#
#                                             orig_url  \
# 0  http://steamcommunity.com/app/4000/homecontent...
# 1  http://steamcommunity.com/app/4000/homecontent...
# 2  http://steamcommunity.com/app/4000/homecontent...
# 3  http://steamcommunity.com/app/4000/homecontent...
# 4  http://steamcommunity.com/app/4000/homecontent...
#
#                                  profile_url       rating  \
# 0        http://steamcommunity.com/id/Xorpik  Recommended
# 1  http://steamcommunity.com/id/rogue_cheney  Recommended
# 2       http://steamcommunity.com/id/hansbro  Recommended
# 3     http://steamcommunity.com/id/starhawk0  Recommended
# 4       http://steamcommunity.com/id/WAFFL32  Recommended
#
#                                               review  \
# 0  Like building games? Get Garry's Mod. Like Rol...
# 1  If you have friends, this is a great game to p...
# 2  i wish i had more time to try this game out al...
# 3  Do I really have to write this review? I am ju...
# 4  Wanna build stuff, get Garry's mod. Wanna play...
#
#                                           review_url  steam_id_number  \
# 0  http://steamcommunity.com/id/Xorpik/recommende...           Xorpik
# 1  http://steamcommunity.com/id/rogue_cheney/reco...     rogue_cheney
# 2  http://steamcommunity.com/id/hansbro/recommend...          hansbro
# 3  http://steamcommunity.com/id/starhawk0/recomme...        starhawk0
# 4  http://steamcommunity.com/id/WAFFL32/recommend...          WAFFL32
#
#    total_game_hours total_game_hours_last_two_weeks  \
# 0             747.1                             0.0
# 1            6940.3                            48.6
# 2           12994.1                            10.6
# 3              82.1                             2.5
# 4             602.6                             3.3
#
#                          username
# 0                          Xorpik
# 1  Rogue Cheney [Away on Holiday]
# 2                            Hans
# 3                      Star_Hawk_
# 4                     Cokewaffles
#
# [5 rows x 27 columns]

# %%
achievement=garry['achievement_progress']
ach=dict(achievement)

# %%
ach
# Out:
# {0: {'num_achievements_attained': 459,
#   'num_achievements_percentage': 0.8861003861003861,
#   'num_achievements_possible': 518},
#  1: {'num_achievements_attained': 29,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 29},
#  2: {'num_achievements_attained': 24,
#   'num_achievements_percentage': 0.827586206896551,
#   'num_achievements_possible': 29},
#  3: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.241379310344827,
#   'num_achievements_possible': 29},
#  4: {'num_achievements_attained': 15,
#   'num_achievements_percentage': 0.5172413793103441,
#   'num_achievements_possible': 29},
#  5: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 20},
#  6: {'num_achievements_attained': 60,
#   'num_achievements_percentage': 0.359281437125748,
#   'num_achievements_possible': 167},
#  7: {'num_achievements_attained': 106,
#   'num_achievements_percentage': 0.634730538922155,
#   'num_achievements_possible': 167},
#  8: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  9: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.33333333333333304,
#   'num_achievements_possible': 24},
#  10: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  11: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.896551724137931,
#   'num_achievements_possible': 29},
#  12: {'num_achievements_attained': 188,
#   'num_achievements_percentage': 0.564564564564564,
#   'num_achievements_possible': 333},
#  13: {'num_achievements_attained': 10,
#   'num_achievements_percentage': 0.344827586206896,
#   'num_achievements_possible': 29},
#  14: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 36},
#  15: {'num_achievements_attained': 409,
#   'num_achievements_percentage': 0.7895752895752891,
#   'num_achievements_possible': 518},
#  16: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  17: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.32307692307692304,
#   'num_achievements_possible': 65},
#  18: {'num_achievements_attained': 3,
#   'num_achievements_percentage': 0.15,
#   'num_achievements_possible': 20},
#  19: {'num_achievements_attained': 301,
#   'num_achievements_percentage': 0.581081081081081,
#   'num_achievements_possible': 518},
#  20: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.689655172413793,
#   'num_achievements_possible': 29},
#  21: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.29230769230769205,
#   'num_achievements_possible': 65},
#  22: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 26},
#  23: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  24: {'num_achievements_attained': 28,
#   'num_achievements_percentage': 0.318181818181818,
#   'num_achievements_possible': 88},
#  25: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  26: {'num_achievements_attained': 44,
#   'num_achievements_percentage': 0.132132132132132,
#   'num_achievements_possible': 333},
#  27: {'num_achievements_attained': 108,
#   'num_achievements_percentage': 0.6467065868263471,
#   'num_achievements_possible': 167},
#  28: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.035714285714285005,
#   'num_achievements_possible': 56},
#  29: {'num_achievements_attained': 34,
#   'num_achievements_percentage': 0.45333333333333303,
#   'num_achievements_possible': 75},
#  30: {'num_achievements_attained': 158,
#   'num_achievements_percentage': 0.9461077844311371,
#   'num_achievements_possible': 167},
#  31: {'num_achievements_attained': 63,
#   'num_achievements_percentage': 0.71590909090909,
#   'num_achievements_possible': 88},
#  32: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  33: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  34: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  35: {'num_achievements_attained': 118,
#   'num_achievements_percentage': 0.893939393939393,
#   'num_achievements_possible': 132},
#  36: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.053030303030303004,
#   'num_achievements_possible': 132},
#  37: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.4375,
#   'num_achievements_possible': 16},
#  38: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.275862068965517,
#   'num_achievements_possible': 29},
#  39: {'num_achievements_attained': 163,
#   'num_achievements_percentage': 0.976047904191616,
#   'num_achievements_possible': 167},
#  40: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.22727272727272702,
#   'num_achievements_possible': 88},
#  41: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.39393939393939303,
#   'num_achievements_possible': 33},
#  42: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  43: {'num_achievements_attained': 167,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 167},
#  44: {'num_achievements_attained': 1,
#   'num_achievements_percentage': 0.025641025641025002,
#   'num_achievements_possible': 39},
#  45: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 52},
#  46: {'num_achievements_attained': 88,
#   'num_achievements_percentage': 0.5269461077844311,
#   'num_achievements_possible': 167},
#  47: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.689655172413793,
#   'num_achievements_possible': 29},
#  48: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  49: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.033333333333333,
#   'num_achievements_possible': 60},
#  50: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.551724137931034,
#   'num_achievements_possible': 29},
#  51: {'num_achievements_attained': 70,
#   'num_achievements_percentage': 0.9333333333333331,
#   'num_achievements_possible': 75},
#  52: {'num_achievements_attained': 117,
#   'num_achievements_percentage': 0.22586872586872503,
#   'num_achievements_possible': 518},
#  53: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  54: {'num_achievements_attained': 367,
#   'num_achievements_percentage': 0.7084942084942081,
#   'num_achievements_possible': 518},
#  55: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  56: {'num_achievements_attained': 240,
#   'num_achievements_percentage': 0.72072072072072,
#   'num_achievements_possible': 333},
#  57: {'num_achievements_attained': 130,
#   'num_achievements_percentage': 0.778443113772455,
#   'num_achievements_possible': 167},
#  58: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  59: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  60: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  61: {'num_achievements_attained': 153,
#   'num_achievements_percentage': 0.916167664670658,
#   'num_achievements_possible': 167},
#  62: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  63: {'num_achievements_attained': 59,
#   'num_achievements_percentage': 0.6704545454545451,
#   'num_achievements_possible': 88},
#  64: {'num_achievements_attained': 69,
#   'num_achievements_percentage': 0.9857142857142851,
#   'num_achievements_possible': 70},
#  65: {'num_achievements_attained': 399,
#   'num_achievements_percentage': 0.7702702702702701,
#   'num_achievements_possible': 518},
#  66: {'num_achievements_attained': 105,
#   'num_achievements_percentage': 0.6287425149700591,
#   'num_achievements_possible': 167},
#  67: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.310344827586206,
#   'num_achievements_possible': 29},
#  68: {'num_achievements_attained': 39,
#   'num_achievements_percentage': 0.233532934131736,
#   'num_achievements_possible': 167},
#  69: {'num_achievements_attained': 17,
#   'num_achievements_percentage': 0.5862068965517241,
#   'num_achievements_possible': 29},
#  70: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  71: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  72: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.9,
#   'num_achievements_possible': 10},
#  73: {'num_achievements_attained': 30,
#   'num_achievements_percentage': 0.5,
#   'num_achievements_possible': 60},
#  74: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  75: {'num_achievements_attained': 129,
#   'num_achievements_percentage': 0.772455089820359,
#   'num_achievements_possible': 167},
#  76: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  77: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  78: {'num_achievements_attained': 31,
#   'num_achievements_percentage': 0.861111111111111,
#   'num_achievements_possible': 36},
#  79: {'num_achievements_attained': 140,
#   'num_achievements_percentage': 0.8383233532934131,
#   'num_achievements_possible': 167},
#  80: {'num_achievements_attained': 34,
#   'num_achievements_percentage': 0.5666666666666661,
#   'num_achievements_possible': 60},
#  81: {'num_achievements_attained': 31,
#   'num_achievements_percentage': 0.46268656716417905,
#   'num_achievements_possible': 67},
#  82: {'num_achievements_attained': 69,
#   'num_achievements_percentage': 0.207207207207207,
#   'num_achievements_possible': 333},
#  83: {'num_achievements_attained': 36,
#   'num_achievements_percentage': 0.24,
#   'num_achievements_possible': 150},
#  84: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 94},
#  85: {'num_achievements_attained': 27,
#   'num_achievements_percentage': 0.45,
#   'num_achievements_possible': 60},
#  86: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  87: {'num_achievements_attained': 297,
#   'num_achievements_percentage': 0.8918918918918911,
#   'num_achievements_possible': 333},
#  88: {'num_achievements_attained': 53,
#   'num_achievements_percentage': 0.360544217687074,
#   'num_achievements_possible': 147},
#  89: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.689655172413793,
#   'num_achievements_possible': 29},
#  90: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.070175438596491,
#   'num_achievements_possible': 57},
#  91: {'num_achievements_attained': 27,
#   'num_achievements_percentage': 0.9310344827586201,
#   'num_achievements_possible': 29},
#  92: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.31666666666666604,
#   'num_achievements_possible': 60},
#  93: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.15151515151515102,
#   'num_achievements_possible': 33},
#  94: {'num_achievements_attained': 155,
#   'num_achievements_percentage': 0.9281437125748501,
#   'num_achievements_possible': 167},
#  95: {'num_achievements_attained': 478,
#   'num_achievements_percentage': 0.922779922779922,
#   'num_achievements_possible': 518},
#  96: {'num_achievements_attained': 115,
#   'num_achievements_percentage': 0.400696864111498,
#   'num_achievements_possible': 287},
#  97: {'num_achievements_attained': 47,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 47},
#  98: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  99: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  100: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  101: {'num_achievements_attained': 133,
#   'num_achievements_percentage': 0.796407185628742,
#   'num_achievements_possible': 167},
#  102: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.4,
#   'num_achievements_possible': 10},
#  103: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 13},
#  104: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.48,
#   'num_achievements_possible': 25},
#  105: {'num_achievements_attained': 80,
#   'num_achievements_percentage': 0.24024024024024002,
#   'num_achievements_possible': 333},
#  106: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.551724137931034,
#   'num_achievements_possible': 29},
#  107: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.022727272727272003,
#   'num_achievements_possible': 88},
#  108: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  109: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  110: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.413793103448275,
#   'num_achievements_possible': 29},
#  111: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.029850746268656,
#   'num_achievements_possible': 67},
#  112: {'num_achievements_attained': 118,
#   'num_achievements_percentage': 0.7065868263473051,
#   'num_achievements_possible': 167},
#  113: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.36666666666666603,
#   'num_achievements_possible': 60},
#  114: {'num_achievements_attained': 35,
#   'num_achievements_percentage': 0.507246376811594,
#   'num_achievements_possible': 69},
#  115: {'num_achievements_attained': 50,
#   'num_achievements_percentage': 0.568181818181818,
#   'num_achievements_possible': 88},
#  116: {'num_achievements_attained': 134,
#   'num_achievements_percentage': 0.8023952095808381,
#   'num_achievements_possible': 167},
#  117: {'num_achievements_attained': 119,
#   'num_achievements_percentage': 0.712574850299401,
#   'num_achievements_possible': 167},
#  118: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.075,
#   'num_achievements_possible': 80},
#  119: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.684210526315789,
#   'num_achievements_possible': 38},
#  120: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.8125,
#   'num_achievements_possible': 16},
#  121: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.122807017543859,
#   'num_achievements_possible': 57},
#  122: {'num_achievements_attained': 40,
#   'num_achievements_percentage': 0.45454545454545403,
#   'num_achievements_possible': 88},
#  123: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 18},
#  124: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.6551724137931031,
#   'num_achievements_possible': 29},
#  125: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 2},
#  126: {'num_achievements_attained': 102,
#   'num_achievements_percentage': 0.693877551020408,
#   'num_achievements_possible': 147},
#  127: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  128: {'num_achievements_attained': 148,
#   'num_achievements_percentage': 0.8862275449101791,
#   'num_achievements_possible': 167},
#  129: {'num_achievements_attained': 51,
#   'num_achievements_percentage': 0.579545454545454,
#   'num_achievements_possible': 88},
#  130: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  131: {'num_achievements_attained': 383,
#   'num_achievements_percentage': 0.739382239382239,
#   'num_achievements_possible': 518},
#  132: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.29411764705882304,
#   'num_achievements_possible': 17},
#  133: {'num_achievements_attained': 128,
#   'num_achievements_percentage': 0.7664670658682631,
#   'num_achievements_possible': 167},
#  134: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  135: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.43103448275862005,
#   'num_achievements_possible': 58},
#  136: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.30645161290322503,
#   'num_achievements_possible': 62},
#  137: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  138: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.344827586206896,
#   'num_achievements_possible': 58},
#  139: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.9,
#   'num_achievements_possible': 10},
#  140: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.620689655172413,
#   'num_achievements_possible': 29},
#  141: {'num_achievements_attained': 55,
#   'num_achievements_percentage': 0.329341317365269,
#   'num_achievements_possible': 167},
#  142: {'num_achievements_attained': 167,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 167},
#  143: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  144: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  145: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.6923076923076921,
#   'num_achievements_possible': 26},
#  146: {'num_achievements_attained': 57,
#   'num_achievements_percentage': 0.647727272727272,
#   'num_achievements_possible': 88},
#  147: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.01255230125523,
#   'num_achievements_possible': 478},
#  148: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.8,
#   'num_achievements_possible': 15},
#  149: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.125748502994011,
#   'num_achievements_possible': 167},
#  150: {'num_achievements_attained': 129,
#   'num_achievements_percentage': 0.772455089820359,
#   'num_achievements_possible': 167},
#  151: {'num_achievements_attained': 227,
#   'num_achievements_percentage': 0.438223938223938,
#   'num_achievements_possible': 518},
#  152: {'num_achievements_attained': 24,
#   'num_achievements_percentage': 0.827586206896551,
#   'num_achievements_possible': 29},
#  153: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.4,
#   'num_achievements_possible': 10},
#  154: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  155: {'num_achievements_attained': 32,
#   'num_achievements_percentage': 0.7619047619047611,
#   'num_achievements_possible': 42},
#  156: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 16},
#  157: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 2},
#  158: {'num_achievements_attained': 98,
#   'num_achievements_percentage': 0.5868263473053891,
#   'num_achievements_possible': 167},
#  159: {'num_achievements_attained': 119,
#   'num_achievements_percentage': 0.712574850299401,
#   'num_achievements_possible': 167},
#  160: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  161: {'num_achievements_attained': 136,
#   'num_achievements_percentage': 0.814371257485029,
#   'num_achievements_possible': 167},
#  162: {'num_achievements_attained': 70,
#   'num_achievements_percentage': 0.7954545454545451,
#   'num_achievements_possible': 88},
#  163: {'num_achievements_attained': 31,
#   'num_achievements_percentage': 0.3875,
#   'num_achievements_possible': 80},
#  164: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.028571428571428,
#   'num_achievements_possible': 70},
#  165: {'num_achievements_attained': 401,
#   'num_achievements_percentage': 0.774131274131274,
#   'num_achievements_possible': 518},
#  166: {'num_achievements_attained': 42,
#   'num_achievements_percentage': 0.251497005988023,
#   'num_achievements_possible': 167},
#  167: {'num_achievements_attained': 50,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 50},
#  168: {'num_achievements_attained': 132,
#   'num_achievements_percentage': 0.790419161676646,
#   'num_achievements_possible': 167},
#  169: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  170: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.42,
#   'num_achievements_possible': 50},
#  171: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.093333333333333,
#   'num_achievements_possible': 75},
#  172: {'num_achievements_attained': 107,
#   'num_achievements_percentage': 0.640718562874251,
#   'num_achievements_possible': 167},
#  173: {'num_achievements_attained': 10,
#   'num_achievements_percentage': 0.47619047619047605,
#   'num_achievements_possible': 21},
#  174: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 14},
#  175: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  176: {'num_achievements_attained': 35,
#   'num_achievements_percentage': 0.25,
#   'num_achievements_possible': 140},
#  177: {'num_achievements_attained': 150,
#   'num_achievements_percentage': 0.8982035928143711,
#   'num_achievements_possible': 167},
#  178: {'num_achievements_attained': 373,
#   'num_achievements_percentage': 0.7200772200772201,
#   'num_achievements_possible': 518},
#  179: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.157894736842105,
#   'num_achievements_possible': 38},
#  180: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  181: {'num_achievements_attained': 304,
#   'num_achievements_percentage': 0.586872586872586,
#   'num_achievements_possible': 518},
#  182: {'num_achievements_attained': 3,
#   'num_achievements_percentage': 0.08571428571428501,
#   'num_achievements_possible': 35},
#  183: {'num_achievements_attained': 69,
#   'num_achievements_percentage': 0.207207207207207,
#   'num_achievements_possible': 333},
#  184: {'num_achievements_attained': 28,
#   'num_achievements_percentage': 0.96551724137931,
#   'num_achievements_possible': 29},
#  185: {'num_achievements_attained': 30,
#   'num_achievements_percentage': 0.461538461538461,
#   'num_achievements_possible': 65},
#  186: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  187: {'num_achievements_attained': 17,
#   'num_achievements_percentage': 0.5862068965517241,
#   'num_achievements_possible': 29},
#  188: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  189: {'num_achievements_attained': 71,
#   'num_achievements_percentage': 0.425149700598802,
#   'num_achievements_possible': 167},
#  190: {'num_achievements_attained': 128,
#   'num_achievements_percentage': 0.7664670658682631,
#   'num_achievements_possible': 167},
#  191: {'num_achievements_attained': 34,
#   'num_achievements_percentage': 0.5666666666666661,
#   'num_achievements_possible': 60},
#  192: {'num_achievements_attained': 289,
#   'num_achievements_percentage': 0.557915057915057,
#   'num_achievements_possible': 518},
#  193: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  194: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 36},
#  195: {'num_achievements_attained': 43,
#   'num_achievements_percentage': 0.716666666666666,
#   'num_achievements_possible': 60},
#  196: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  197: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.478260869565217,
#   'num_achievements_possible': 46},
#  198: {'num_achievements_attained': 251,
#   'num_achievements_percentage': 0.7537537537537531,
#   'num_achievements_possible': 333},
#  199: {'num_achievements_attained': 157,
#   'num_achievements_percentage': 0.9401197604790411,
#   'num_achievements_possible': 167},
#  200: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.176870748299319,
#   'num_achievements_possible': 147},
#  201: {'num_achievements_attained': 36,
#   'num_achievements_percentage': 0.553846153846153,
#   'num_achievements_possible': 65},
#  202: {'num_achievements_attained': 10,
#   'num_achievements_percentage': 0.133333333333333,
#   'num_achievements_possible': 75},
#  203: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  204: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  205: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.46666666666666606,
#   'num_achievements_possible': 45},
#  206: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.20754716981132001,
#   'num_achievements_possible': 106},
#  207: {'num_achievements_attained': 65,
#   'num_achievements_percentage': 0.7386363636363631,
#   'num_achievements_possible': 88},
#  208: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  209: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  210: {'num_achievements_attained': 329,
#   'num_achievements_percentage': 0.6351351351351351,
#   'num_achievements_possible': 518},
#  211: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 50},
#  212: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.551724137931034,
#   'num_achievements_possible': 29},
#  213: {'num_achievements_attained': 74,
#   'num_achievements_percentage': 0.44311377245508904,
#   'num_achievements_possible': 167},
#  214: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.896551724137931,
#   'num_achievements_possible': 29},
#  215: {'num_achievements_attained': 496,
#   'num_achievements_percentage': 0.9575289575289571,
#   'num_achievements_possible': 518},
#  216: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.1,
#   'num_achievements_possible': 20},
#  217: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.18181818181818102,
#   'num_achievements_possible': 11},
#  218: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  219: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  220: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.241379310344827,
#   'num_achievements_possible': 29},
#  221: {'num_achievements_attained': 1,
#   'num_achievements_percentage': 0.020833333333333003,
#   'num_achievements_possible': 48},
#  222: {'num_achievements_attained': 440,
#   'num_achievements_percentage': 0.8494208494208491,
#   'num_achievements_possible': 518},
#  223: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  224: {'num_achievements_attained': 132,
#   'num_achievements_percentage': 0.790419161676646,
#   'num_achievements_possible': 167},
#  225: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.033333333333333,
#   'num_achievements_possible': 60},
#  226: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.24615384615384603,
#   'num_achievements_possible': 65},
#  227: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  228: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 77},
#  229: {'num_achievements_attained': 430,
#   'num_achievements_percentage': 0.83011583011583,
#   'num_achievements_possible': 518},
#  230: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  231: {'num_achievements_attained': 71,
#   'num_achievements_percentage': 0.425149700598802,
#   'num_achievements_possible': 167},
#  232: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.8620689655172411,
#   'num_achievements_possible': 29},
#  233: {'num_achievements_attained': 27,
#   'num_achievements_percentage': 0.9310344827586201,
#   'num_achievements_possible': 29},
#  234: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  235: {'num_achievements_attained': 95,
#   'num_achievements_percentage': 0.5688622754491011,
#   'num_achievements_possible': 167},
#  236: {'num_achievements_attained': 56,
#   'num_achievements_percentage': 0.636363636363636,
#   'num_achievements_possible': 88},
#  237: {'num_achievements_attained': 123,
#   'num_achievements_percentage': 0.736526946107784,
#   'num_achievements_possible': 167},
#  238: {'num_achievements_attained': 391,
#   'num_achievements_percentage': 0.7548262548262541,
#   'num_achievements_possible': 518},
#  239: {'num_achievements_attained': 60,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 60},
#  240: {'num_achievements_attained': 40,
#   'num_achievements_percentage': 0.533333333333333,
#   'num_achievements_possible': 75},
#  241: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 15},
#  242: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  243: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  244: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.12195121951219501,
#   'num_achievements_possible': 41},
#  245: {'num_achievements_attained': 101,
#   'num_achievements_percentage': 0.6047904191616761,
#   'num_achievements_possible': 167},
#  246: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.28571428571428503,
#   'num_achievements_possible': 28},
#  247: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.266666666666666,
#   'num_achievements_possible': 15},
#  248: {'num_achievements_attained': 101,
#   'num_achievements_percentage': 0.6047904191616761,
#   'num_achievements_possible': 167},
#  249: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.416666666666666,
#   'num_achievements_possible': 48},
#  250: {'num_achievements_attained': 113,
#   'num_achievements_percentage': 0.6348314606741571,
#   'num_achievements_possible': 178},
#  251: {'num_achievements_attained': 167,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 167},
#  252: {'num_achievements_attained': 514,
#   'num_achievements_percentage': 0.9922779922779921,
#   'num_achievements_possible': 518},
#  253: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 33},
#  254: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  255: {'num_achievements_attained': 17,
#   'num_achievements_percentage': 0.28333333333333305,
#   'num_achievements_possible': 60},
#  256: {'num_achievements_attained': 125,
#   'num_achievements_percentage': 0.375375375375375,
#   'num_achievements_possible': 333},
#  257: {'num_achievements_attained': 438,
#   'num_achievements_percentage': 0.8455598455598451,
#   'num_achievements_possible': 518},
#  258: {'num_achievements_attained': 28,
#   'num_achievements_percentage': 0.96551724137931,
#   'num_achievements_possible': 29},
#  259: {'num_achievements_attained': 17,
#   'num_achievements_percentage': 0.204819277108433,
#   'num_achievements_possible': 83},
#  260: {'num_achievements_attained': 3,
#   'num_achievements_percentage': 0.08571428571428501,
#   'num_achievements_possible': 35},
#  261: {'num_achievements_attained': 280,
#   'num_achievements_percentage': 0.54054054054054,
#   'num_achievements_possible': 518},
#  262: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  263: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  264: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.060060060060060004,
#   'num_achievements_possible': 333},
#  265: {'num_achievements_attained': 10,
#   'num_achievements_percentage': 0.344827586206896,
#   'num_achievements_possible': 29},
#  266: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 19},
#  267: {'num_achievements_attained': 99,
#   'num_achievements_percentage': 0.592814371257485,
#   'num_achievements_possible': 167},
#  268: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  269: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.5,
#   'num_achievements_possible': 10},
#  270: {'num_achievements_attained': 64,
#   'num_achievements_percentage': 0.7272727272727271,
#   'num_achievements_possible': 88},
#  271: {'num_achievements_attained': 49,
#   'num_achievements_percentage': 0.11835748792270501,
#   'num_achievements_possible': 414},
#  272: {'num_achievements_attained': 513,
#   'num_achievements_percentage': 0.99034749034749,
#   'num_achievements_possible': 518},
#  273: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  274: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  275: {'num_achievements_attained': 159,
#   'num_achievements_percentage': 0.952095808383233,
#   'num_achievements_possible': 167},
#  276: {'num_achievements_attained': 347,
#   'num_achievements_percentage': 0.6698841698841691,
#   'num_achievements_possible': 518},
#  277: {'num_achievements_attained': 59,
#   'num_achievements_percentage': 0.6704545454545451,
#   'num_achievements_possible': 88},
#  278: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.016393442622950002,
#   'num_achievements_possible': 122},
#  279: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  280: {'num_achievements_attained': 40,
#   'num_achievements_percentage': 0.45454545454545403,
#   'num_achievements_possible': 88},
#  281: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.620689655172413,
#   'num_achievements_possible': 29},
#  282: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.416666666666666,
#   'num_achievements_possible': 60},
#  283: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.620689655172413,
#   'num_achievements_possible': 29},
#  284: {'num_achievements_attained': 144,
#   'num_achievements_percentage': 0.8622754491017961,
#   'num_achievements_possible': 167},
#  285: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.7878787878787871,
#   'num_achievements_possible': 33},
#  286: {'num_achievements_attained': 140,
#   'num_achievements_percentage': 0.8383233532934131,
#   'num_achievements_possible': 167},
#  287: {'num_achievements_attained': 10,
#   'num_achievements_percentage': 0.204081632653061,
#   'num_achievements_possible': 49},
#  288: {'num_achievements_attained': 158,
#   'num_achievements_percentage': 0.9461077844311371,
#   'num_achievements_possible': 167},
#  289: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.4,
#   'num_achievements_possible': 15},
#  290: {'num_achievements_attained': 1,
#   'num_achievements_percentage': 0.047619047619047006,
#   'num_achievements_possible': 21},
#  291: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 14},
#  292: {'num_achievements_attained': 32,
#   'num_achievements_percentage': 0.42666666666666603,
#   'num_achievements_possible': 75},
#  293: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.11111111111111101,
#   'num_achievements_possible': 36},
#  294: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.413793103448275,
#   'num_achievements_possible': 29},
#  295: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.172413793103448,
#   'num_achievements_possible': 29},
#  296: {'num_achievements_attained': 127,
#   'num_achievements_percentage': 0.7604790419161671,
#   'num_achievements_possible': 167},
#  297: {'num_achievements_attained': 34,
#   'num_achievements_percentage': 0.425,
#   'num_achievements_possible': 80},
#  298: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  299: {'num_achievements_attained': 271,
#   'num_achievements_percentage': 0.523166023166023,
#   'num_achievements_possible': 518},
#  300: {'num_achievements_attained': 443,
#   'num_achievements_percentage': 0.8552123552123551,
#   'num_achievements_possible': 518},
#  301: {'num_achievements_attained': 61,
#   'num_achievements_percentage': 0.365269461077844,
#   'num_achievements_possible': 167},
#  302: {'num_achievements_attained': 107,
#   'num_achievements_percentage': 0.640718562874251,
#   'num_achievements_possible': 167},
#  303: {'num_achievements_attained': 52,
#   'num_achievements_percentage': 0.658227848101265,
#   'num_achievements_possible': 79},
#  304: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.416666666666666,
#   'num_achievements_possible': 60},
#  305: {'num_achievements_attained': 95,
#   'num_achievements_percentage': 0.5688622754491011,
#   'num_achievements_possible': 167},
#  306: {'num_achievements_attained': 31,
#   'num_achievements_percentage': 0.41333333333333305,
#   'num_achievements_possible': 75},
#  307: {'num_achievements_attained': 23,
#   'num_achievements_percentage': 0.7931034482758621,
#   'num_achievements_possible': 29},
#  308: {'num_achievements_attained': 28,
#   'num_achievements_percentage': 0.08408408408408401,
#   'num_achievements_possible': 333},
#  309: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.10389610389610301,
#   'num_achievements_possible': 77},
#  310: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.18333333333333302,
#   'num_achievements_possible': 60},
#  311: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.758620689655172,
#   'num_achievements_possible': 29},
#  312: {'num_achievements_attained': 81,
#   'num_achievements_percentage': 0.48502994011976003,
#   'num_achievements_possible': 167},
#  313: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.040816326530612006,
#   'num_achievements_possible': 49},
#  314: {'num_achievements_attained': 49,
#   'num_achievements_percentage': 0.337931034482758,
#   'num_achievements_possible': 145},
#  315: {'num_achievements_attained': 30,
#   'num_achievements_percentage': 0.34090909090909005,
#   'num_achievements_possible': 88},
#  316: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.6551724137931031,
#   'num_achievements_possible': 29},
#  317: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.206896551724137,
#   'num_achievements_possible': 29},
#  318: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  319: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.384615384615384,
#   'num_achievements_possible': 65},
#  320: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.11976047904191602,
#   'num_achievements_possible': 167},
#  321: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.48484848484848403,
#   'num_achievements_possible': 33},
#  322: {'num_achievements_attained': 352,
#   'num_achievements_percentage': 0.6795366795366791,
#   'num_achievements_possible': 518},
#  323: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 75},
#  324: {'num_achievements_attained': 67,
#   'num_achievements_percentage': 0.129343629343629,
#   'num_achievements_possible': 518},
#  325: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  326: {'num_achievements_attained': 1,
#   'num_achievements_percentage': 0.066666666666666,
#   'num_achievements_possible': 15},
#  327: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  328: {'num_achievements_attained': 104,
#   'num_achievements_percentage': 0.6227544910179641,
#   'num_achievements_possible': 167},
#  329: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  330: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  331: {'num_achievements_attained': 78,
#   'num_achievements_percentage': 0.59090909090909,
#   'num_achievements_possible': 132},
#  332: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.066666666666666,
#   'num_achievements_possible': 285},
#  333: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 36},
#  334: {'num_achievements_attained': 332,
#   'num_achievements_percentage': 0.6409266409266411,
#   'num_achievements_possible': 518},
#  335: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  336: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.31666666666666604,
#   'num_achievements_possible': 60},
#  337: {'num_achievements_attained': 130,
#   'num_achievements_percentage': 0.778443113772455,
#   'num_achievements_possible': 167},
#  338: {'num_achievements_attained': 15,
#   'num_achievements_percentage': 0.5172413793103441,
#   'num_achievements_possible': 29},
#  339: {'num_achievements_attained': 3,
#   'num_achievements_percentage': 0.30000000000000004,
#   'num_achievements_possible': 10},
#  340: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.310344827586206,
#   'num_achievements_possible': 29},
#  341: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 36},
#  342: {'num_achievements_attained': 3,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 3},
#  343: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  344: {'num_achievements_attained': 122,
#   'num_achievements_percentage': 0.730538922155688,
#   'num_achievements_possible': 167},
#  345: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  346: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  347: {'num_achievements_attained': 290,
#   'num_achievements_percentage': 0.5598455598455591,
#   'num_achievements_possible': 518},
#  348: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.620689655172413,
#   'num_achievements_possible': 29},
#  349: {'num_achievements_attained': 159,
#   'num_achievements_percentage': 0.8932584269662921,
#   'num_achievements_possible': 178},
#  350: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  351: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  352: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 16},
#  353: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.551724137931034,
#   'num_achievements_possible': 29},
#  354: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.7241379310344821,
#   'num_achievements_possible': 29},
#  355: {'num_achievements_attained': 52,
#   'num_achievements_percentage': 0.59090909090909,
#   'num_achievements_possible': 88},
#  356: {'num_achievements_attained': 156,
#   'num_achievements_percentage': 0.934131736526946,
#   'num_achievements_possible': 167},
#  357: {'num_achievements_attained': 65,
#   'num_achievements_percentage': 0.389221556886227,
#   'num_achievements_possible': 167},
#  358: {'num_achievements_attained': 140,
#   'num_achievements_percentage': 0.8383233532934131,
#   'num_achievements_possible': 167},
#  359: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  360: {'num_achievements_attained': 70,
#   'num_achievements_percentage': 0.419161676646706,
#   'num_achievements_possible': 167},
#  361: {'num_achievements_attained': 1,
#   'num_achievements_percentage': 0.019607843137254003,
#   'num_achievements_possible': 51},
#  362: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.8,
#   'num_achievements_possible': 10},
#  363: {'num_achievements_attained': 270,
#   'num_achievements_percentage': 0.5212355212355211,
#   'num_achievements_possible': 518},
#  364: {'num_achievements_attained': 83,
#   'num_achievements_percentage': 0.628787878787878,
#   'num_achievements_possible': 132},
#  365: {'num_achievements_attained': 68,
#   'num_achievements_percentage': 0.772727272727272,
#   'num_achievements_possible': 88},
#  366: {'num_achievements_attained': 370,
#   'num_achievements_percentage': 0.7142857142857141,
#   'num_achievements_possible': 518},
#  367: {'num_achievements_attained': 40,
#   'num_achievements_percentage': 0.6153846153846151,
#   'num_achievements_possible': 65},
#  368: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  369: {'num_achievements_attained': 38,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 38},
#  370: {'num_achievements_attained': 443,
#   'num_achievements_percentage': 0.8552123552123551,
#   'num_achievements_possible': 518},
#  371: {'num_achievements_attained': 275,
#   'num_achievements_percentage': 0.8258258258258251,
#   'num_achievements_possible': 333},
#  372: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.6551724137931031,
#   'num_achievements_possible': 29},
#  373: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  374: {'num_achievements_attained': 513,
#   'num_achievements_percentage': 0.99034749034749,
#   'num_achievements_possible': 518},
#  375: {'num_achievements_attained': 309,
#   'num_achievements_percentage': 0.596525096525096,
#   'num_achievements_possible': 518},
#  376: {'num_achievements_attained': 111,
#   'num_achievements_percentage': 0.6646706586826341,
#   'num_achievements_possible': 167},
#  377: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  378: {'num_achievements_attained': 165,
#   'num_achievements_percentage': 0.9880239520958081,
#   'num_achievements_possible': 167},
#  379: {'num_achievements_attained': 101,
#   'num_achievements_percentage': 0.6047904191616761,
#   'num_achievements_possible': 167},
#  380: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.413793103448275,
#   'num_achievements_possible': 29},
#  381: {'num_achievements_attained': 116,
#   'num_achievements_percentage': 0.694610778443113,
#   'num_achievements_possible': 167},
#  382: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 94},
# ...
#  872: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  873: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  874: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.1,
#   'num_achievements_possible': 50},
#  875: {'num_achievements_attained': 143,
#   'num_achievements_percentage': 0.8562874251497,
#   'num_achievements_possible': 167},
#  876: {'num_achievements_attained': 105,
#   'num_achievements_percentage': 0.8606557377049181,
#   'num_achievements_possible': 122},
#  877: {'num_achievements_attained': 493,
#   'num_achievements_percentage': 0.9517374517374511,
#   'num_achievements_possible': 518},
#  878: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.185185185185185,
#   'num_achievements_possible': 27},
#  879: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  880: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  881: {'num_achievements_attained': 6,
#   'num_achievements_percentage': 0.206896551724137,
#   'num_achievements_possible': 29},
#  882: {'num_achievements_attained': 330,
#   'num_achievements_percentage': 0.637065637065637,
#   'num_achievements_possible': 518},
#  883: {'num_achievements_attained': 167,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 167},
#  884: {'num_achievements_attained': 31,
#   'num_achievements_percentage': 0.44927536231884,
#   'num_achievements_possible': 69},
#  885: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.583333333333333,
#   'num_achievements_possible': 36},
#  886: {'num_achievements_attained': 2,
#   'num_achievements_percentage': 0.025,
#   'num_achievements_possible': 80},
#  887: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  888: {'num_achievements_attained': 29,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 29},
#  889: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  890: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  891: {'num_achievements_attained': 15,
#   'num_achievements_percentage': 0.5172413793103441,
#   'num_achievements_possible': 29},
#  892: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.275862068965517,
#   'num_achievements_possible': 29},
#  893: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  894: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  895: {'num_achievements_attained': 32,
#   'num_achievements_percentage': 0.4,
#   'num_achievements_possible': 80},
#  896: {'num_achievements_attained': 148,
#   'num_achievements_percentage': 0.8862275449101791,
#   'num_achievements_possible': 167},
#  897: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  898: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 21},
#  899: {'num_achievements_attained': 32,
#   'num_achievements_percentage': 0.533333333333333,
#   'num_achievements_possible': 60},
#  900: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.12359550561797701,
#   'num_achievements_possible': 178},
#  901: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.185185185185185,
#   'num_achievements_possible': 27},
#  902: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.583333333333333,
#   'num_achievements_possible': 36},
#  903: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  904: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  905: {'num_achievements_attained': 371,
#   'num_achievements_percentage': 0.716216216216216,
#   'num_achievements_possible': 518},
#  906: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  907: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  908: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.171428571428571,
#   'num_achievements_possible': 70},
#  909: {'num_achievements_attained': 24,
#   'num_achievements_percentage': 0.827586206896551,
#   'num_achievements_possible': 29},
#  910: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  911: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  912: {'num_achievements_attained': 162,
#   'num_achievements_percentage': 0.312741312741312,
#   'num_achievements_possible': 518},
#  913: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  914: {'num_achievements_attained': 29,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 29},
#  915: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.413793103448275,
#   'num_achievements_possible': 29},
#  916: {'num_achievements_attained': 99,
#   'num_achievements_percentage': 0.592814371257485,
#   'num_achievements_possible': 167},
#  917: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  918: {'num_achievements_attained': 28,
#   'num_achievements_percentage': 0.4,
#   'num_achievements_possible': 70},
#  919: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  920: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.689655172413793,
#   'num_achievements_possible': 29},
#  921: {'num_achievements_attained': 144,
#   'num_achievements_percentage': 0.8622754491017961,
#   'num_achievements_possible': 167},
#  922: {'num_achievements_attained': 162,
#   'num_achievements_percentage': 0.312741312741312,
#   'num_achievements_possible': 518},
#  923: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  924: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  925: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 60},
#  926: {'num_achievements_attained': 37,
#   'num_achievements_percentage': 0.7872340425531911,
#   'num_achievements_possible': 47},
#  927: {'num_achievements_attained': 101,
#   'num_achievements_percentage': 0.55191256830601,
#   'num_achievements_possible': 183},
#  928: {'num_achievements_attained': 113,
#   'num_achievements_percentage': 0.676646706586826,
#   'num_achievements_possible': 167},
#  929: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.275862068965517,
#   'num_achievements_possible': 29},
#  930: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.310344827586206,
#   'num_achievements_possible': 29},
#  931: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  932: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 167},
#  933: {'num_achievements_attained': 349,
#   'num_achievements_percentage': 0.6737451737451731,
#   'num_achievements_possible': 518},
#  934: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.171428571428571,
#   'num_achievements_possible': 70},
#  935: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  936: {'num_achievements_attained': 7,
#   'num_achievements_percentage': 0.241379310344827,
#   'num_achievements_possible': 29},
#  937: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  938: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  939: {'num_achievements_attained': 72,
#   'num_achievements_percentage': 0.8571428571428571,
#   'num_achievements_possible': 84},
#  940: {'num_achievements_attained': 27,
#   'num_achievements_percentage': 0.9310344827586201,
#   'num_achievements_possible': 29},
#  941: {'num_achievements_attained': 293,
#   'num_achievements_percentage': 0.5656370656370651,
#   'num_achievements_possible': 518},
#  942: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.275862068965517,
#   'num_achievements_possible': 29},
#  943: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.5,
#   'num_achievements_possible': 10},
#  944: {'num_achievements_attained': 514,
#   'num_achievements_percentage': 0.9922779922779921,
#   'num_achievements_possible': 518},
#  945: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.322033898305084,
#   'num_achievements_possible': 59},
#  946: {'num_achievements_attained': 137,
#   'num_achievements_percentage': 0.8203592814371251,
#   'num_achievements_possible': 167},
#  947: {'num_achievements_attained': 29,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 29},
#  948: {'num_achievements_attained': 24,
#   'num_achievements_percentage': 0.827586206896551,
#   'num_achievements_possible': 29},
#  949: {'num_achievements_attained': 16,
#   'num_achievements_percentage': 0.24615384615384603,
#   'num_achievements_possible': 65},
#  950: {'num_achievements_attained': 365,
#   'num_achievements_percentage': 0.704633204633204,
#   'num_achievements_possible': 518},
#  951: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.553191489361702,
#   'num_achievements_possible': 47},
#  952: {'num_achievements_attained': 20,
#   'num_achievements_percentage': 0.22727272727272702,
#   'num_achievements_possible': 88},
#  953: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 0.171428571428571,
#   'num_achievements_possible': 70},
#  954: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.22222222222222202,
#   'num_achievements_possible': 36},
#  955: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 2},
#  956: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  957: {'num_achievements_attained': 145,
#   'num_achievements_percentage': 0.8682634730538921,
#   'num_achievements_possible': 167},
#  958: {'num_achievements_attained': 5,
#   'num_achievements_percentage': 0.5,
#   'num_achievements_possible': 10},
#  959: {'num_achievements_attained': 8,
#   'num_achievements_percentage': 0.22222222222222202,
#   'num_achievements_possible': 36},
#  960: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 2},
#  961: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  962: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.204545454545454,
#   'num_achievements_possible': 88},
#  963: {'num_achievements_attained': 65,
#   'num_achievements_percentage': 0.7386363636363631,
#   'num_achievements_possible': 88},
#  964: {'num_achievements_attained': 145,
#   'num_achievements_percentage': 0.8682634730538921,
#   'num_achievements_possible': 167},
#  965: {'num_achievements_attained': 121,
#   'num_achievements_percentage': 0.7245508982035921,
#   'num_achievements_possible': 167},
#  966: {'num_achievements_attained': 12,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 12},
#  967: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.125,
#   'num_achievements_possible': 88},
#  968: {'num_achievements_attained': 23,
#   'num_achievements_percentage': 0.7931034482758621,
#   'num_achievements_possible': 29},
#  969: {'num_achievements_attained': 23,
#   'num_achievements_percentage': 0.7931034482758621,
#   'num_achievements_possible': 29},
#  970: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.42424242424242403,
#   'num_achievements_possible': 33},
#  971: {'num_achievements_attained': 92,
#   'num_achievements_percentage': 0.550898203592814,
#   'num_achievements_possible': 167},
#  972: {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 88},
#  973: {'num_achievements_attained': 4,
#   'num_achievements_percentage': 0.16666666666666602,
#   'num_achievements_possible': 24},
#  974: {'num_achievements_attained': 137,
#   'num_achievements_percentage': 0.8203592814371251,
#   'num_achievements_possible': 167},
#  975: {'num_achievements_attained': 23,
#   'num_achievements_percentage': 0.35384615384615303,
#   'num_achievements_possible': 65},
#  976: {'num_achievements_attained': 333,
#   'num_achievements_percentage': 0.642857142857142,
#   'num_achievements_possible': 518},
#  977: {'num_achievements_attained': 121,
#   'num_achievements_percentage': 0.7245508982035921,
#   'num_achievements_possible': 167},
#  978: {'num_achievements_attained': 141,
#   'num_achievements_percentage': 0.8443113772455091,
#   'num_achievements_possible': 167},
#  979: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.6551724137931031,
#   'num_achievements_possible': 29},
#  980: {'num_achievements_attained': 363,
#   'num_achievements_percentage': 0.7007722007722,
#   'num_achievements_possible': 518},
#  981: {'num_achievements_attained': 22,
#   'num_achievements_percentage': 0.36666666666666603,
#   'num_achievements_possible': 60},
#  982: {'num_achievements_attained': 19,
#   'num_achievements_percentage': 0.31666666666666604,
#   'num_achievements_possible': 60},
#  983: {'num_achievements_attained': 26,
#   'num_achievements_percentage': 0.6190476190476191,
#   'num_achievements_possible': 42},
#  984: {'num_achievements_attained': 9,
#   'num_achievements_percentage': 0.310344827586206,
#   'num_achievements_possible': 29},
#  985: {'num_achievements_attained': 18,
#   'num_achievements_percentage': 0.620689655172413,
#   'num_achievements_possible': 29},
#  986: {'num_achievements_attained': 122,
#   'num_achievements_percentage': 0.730538922155688,
#   'num_achievements_possible': 167},
#  987: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.7222222222222221,
#   'num_achievements_possible': 18},
#  988: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.482758620689655,
#   'num_achievements_possible': 29},
#  989: {'num_achievements_attained': 167,
#   'num_achievements_percentage': 1.0,
#   'num_achievements_possible': 167},
#  990: {'num_achievements_attained': 13,
#   'num_achievements_percentage': 0.448275862068965,
#   'num_achievements_possible': 29},
#  991: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.8620689655172411,
#   'num_achievements_possible': 29},
#  992: {'num_achievements_attained': 25,
#   'num_achievements_percentage': 0.301204819277108,
#   'num_achievements_possible': 83},
#  993: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  994: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  995: {'num_achievements_attained': 11,
#   'num_achievements_percentage': 0.379310344827586,
#   'num_achievements_possible': 29},
#  996: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  997: {'num_achievements_attained': None,
#   'num_achievements_percentage': None,
#   'num_achievements_possible': None},
#  998: {'num_achievements_attained': 21,
#   'num_achievements_percentage': 0.238636363636363,
#   'num_achievements_possible': 88},
#  999: {'num_achievements_attained': 14,
#   'num_achievements_percentage': 0.518518518518518,
#   'num_achievements_possible': 27},
#  ...}

# %% [markdown]
# To do:
# 1.	separate category that decide how good a game is (rating, editors choice, etc)
# 2.	determine what defines a ‘quality review’ i.e. decide what to use when determining a trustworthy reviewer(length of game play, community badge, etc)
# 3.	find out how to get info from written reviews themselves
#
# Info from reviews => game perks extracted
# Gamer => games they play => categorize what they like or dislike => recommend games accordingly
#
# How to sort the games that are being recommended?
# Ratings? Relevance?
